# %%
from recognizer import FaceRecognizer
# Out:
# WARNING:tensorflow:From e:\venv\torchvenv\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
recog = FaceRecognizer(model_name="Facenet")  # hoặc "ArcFace", "VGG-Face", v.v.

# %%
img1 = recog.load_image("face_image1.jpg")
embedding1 = recog.get_embedding(img1)

img2 = recog.load_image("face_image2.jpg")
embedding2 = recog.get_embedding(img2)

# %%
print(recog.is_match(embedding1, embedding2))
# Out:
# True
